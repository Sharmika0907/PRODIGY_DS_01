# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharmika0907/PRODIGY_DS_01/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
titanic = sns.load_dataset('titanic')

print(titanic.head())
print(titanic['age'].describe())
print(titanic['sex'].value_counts())

import matplotlib.pyplot as plt
titanic['sex'].value_counts().plot(kind='bar', color=['skyblue', 'lightcoral'])

plt.title('Distribution of Genders on Titanic')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
titanic['age'].dropna().plot(kind='hist', bins=30, color='lightgreen')

plt.title('Distribution of Ages on Titanic')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64
# sex
# ...

# %%
import seaborn as sns
import pandas as pd
titanic = sns.load_dataset('titanic')

print(titanic.head())
print(titanic['age'].describe())
print(titanic['sex'].value_counts())

import matplotlib.pyplot as plt
titanic['sex'].value_counts().plot(kind='bar', color=['skyblue', 'lightcoral'])

plt.title('Distribution of Genders on Titanic')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

titanic['age'].dropna().plot(kind='hist', bins=30, color='lightgreen')

plt.title('Distribution of Ages on Titanic')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64
# sex
# ...
